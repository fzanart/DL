# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
import numpy as np

# %%
# from https://arxiv.org/abs/2208.00269
labels = ['Application software',
        'Documentation',
        'Non-web libraries and frameworks',
        'Software tools',
        'System software',
        'Web libraries and frameworks']
confusion_matrix = np.array([[20,0,8,11,0,4],
                        [1,26,2,2,0,12],
                        [5,4,108,10,2,14],
                        [3,3,10,69,1,10],
                        [0,1,3,7,6,1],
                        [1,3,14,7,0,127]])

y_true = []
y_pred = []

for i in range(len(confusion_matrix)):
    for j in range(len(confusion_matrix[i])):
        y_true += [i] * confusion_matrix[i][j]
        y_pred += [j] * confusion_matrix[i][j]


# calculate precision, recall, and f1-score for each class
report = classification_report(y_true,y_pred, target_names=labels)

print('BASELINE')
print(report)

ConfusionMatrixDisplay(confusion_matrix=confusion_matrix, display_labels=labels).plot(xticks_rotation='vertical')
# Out:
# BASELINE
#                                   precision    recall  f1-score   support
#
#             Application software       0.67      0.47      0.55        43
#                    Documentation       0.70      0.60      0.65        43
# Non-web libraries and frameworks       0.74      0.76      0.75       143
#                   Software tools       0.65      0.72      0.68        96
#                  System software       0.67      0.33      0.44        18
#     Web libraries and frameworks       0.76      0.84      0.79       152
#
#                         accuracy                           0.72       495
#                        macro avg       0.70      0.62      0.64       495
#                     weighted avg       0.72      0.72      0.71       495
