# %%
import pandas as pd
from markdown import Markdown
from io import StringIO
from html.parser import HTMLParser
import re

# %%
def unmark_element(element, stream=None):
    if stream is None:
        stream = StringIO()
    if element.text:
        stream.write(element.text)
    for sub in element:
        unmark_element(sub, stream)
    if element.tail:
        stream.write(element.tail)
    return stream.getvalue()


# patching Markdown
Markdown.output_formats["plain"] = unmark_element
__md = Markdown(output_format="plain")
__md.stripTopLevelTags = False


def unmark(text):
    return __md.convert(text)


class MLStripper(HTMLParser):
    def __init__(self):
        super().__init__()
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.text = StringIO()
    def handle_data(self, d):
        self.text.write(d)
    def get_data(self):
        return self.text.getvalue()

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()


def clean_text(text):
    # delete codeblocks
    text = re.sub(r"```.*?```", " ", text, 0, re.DOTALL) # count=0 means all occurrences will be replaced.
    # delete markdown tags
    text = unmark(text)
    # delete html tags
    text = strip_tags(text)
    # delete non ascii char
    text = text.encode('ascii', 'ignore').decode('utf-8', 'ignore')
    # delete extra whitespaces
    text = re.sub(r'\s+', ' ', text,0, re.DOTALL)
    text = re.sub('\s{2,}', ' ', text, 0, re.DOTALL)

    return text

# %%
df = pd.read_csv('GHDomains_cleaned.csv')
df
# Out:
#          Stars    Forks                                        Description  \
# 0     323943.0  25410.0  freeCodeCamp.org's open source codebase and cu...
# 1     150012.0  71296.0  The most popular HTML, CSS, and JavaScript fra...
# 2      96800.0  22341.0  Bring data to life with SVG, Canvas and HTML. ...
# 3     168294.0  33061.0  A declarative, efficient, and flexible JavaScr...
# 4      59608.0  28135.0            AngularJS - HTML enhanced for web apps!
# ...        ...      ...                                                ...
# 4995    1850.0    349.0  This project aims to provide a working page fl...
# 4996    1780.0    178.0  JavaScript Client-Side Cookie Manipulation Lib...
# 4997    3138.0    300.0  The earliest versions of the very first c comp...
# 4998    1668.0    441.0  A clone of the UIImagePickerController using t...
# 4999    2926.0    722.0  Mapnik is an open source toolkit for developin...
#
#                                                  Readme  \
# 0     ![freeCodeCamp.org Social Banner](https://s3.a...
# 1     <p align="center">\n  <a href="https://getboot...
# 2     # D3: Data-Driven Documents\n\n<a href="https:...
# 3     # [React](https://reactjs.org/) &middot; [![Gi...
# 4     AngularJS [![CircleCI](https://circleci.com/gh...
# ...                                                 ...
# 4995  # Changes:\n\n  * Made clickable views like a ...
# 4996  # Cookies.js\n\nCookies.js is a small client-s...
# 4997  legacy-cc\n=========\n\nThe earliest versions ...
# 4998  # ELCImagePickerController\n\n*A clone of the ...
# 4999  ```\n    _/      _/                           ...
#
#                                               Languages  \
# 0     ['JavaScript', 'CSS', 'Shell', 'HTML', 'EJS', ...
# 1     ['JavaScript', 'HTML', 'SCSS', 'CSS', 'PowerSh...
# 2                                        ['JavaScript']
# 3     ['JavaScript', 'HTML', 'CSS', 'C++', 'TypeScri...
# 4         ['JavaScript', 'HTML', 'Shell', 'PHP', 'CSS']
# ...                                                 ...
# 4995                                           ['Java']
# 4996                      ['JavaScript', 'CSS', 'HTML']
# 4997                                  ['C', 'Assembly']
# 4998                            ['Objective-C', 'Ruby']
# 4999  ['XSLT', 'C++', 'Python', 'HTML', 'JavaScript'...
#
#                                       Licence  Releases  Status  \
# 0     BSD 3-Clause "New" or "Revised" License       0.0    True
# 1                                 MIT License      69.0    True
# 2     BSD 3-Clause "New" or "Revised" License     167.0    True
# 3                                 MIT License      96.0    True
# 4                                 MIT License       0.0    True
# ...                                       ...       ...     ...
# 4995                                      NaN       0.0    True
# 4996                            The Unlicense      10.0    True
# 4997                                      NaN       0.0    True
# 4998                                      NaN       1.0    True
# 4999   GNU Lesser General Public License v2.1      13.0    True
#
#                                                Contents  \
# 0     ['.dockerignore', '.editorconfig', '.eslintign...
# 1     ['.babelrc.js', '.browserslistrc', '.bundlewat...
# 2     ['.gitignore', 'API.md', 'CHANGES.md', 'ISSUE_...
# 3     ['.circleci', '.codesandbox', '.editorconfig',...
# 4     ['.circleci', '.editorconfig', '.eslintignore'...
# ...                                                 ...
# 4995  ['.gitignore', 'README.md', 'build.gradle', 'f...
# 4996  ['.gitignore', 'CHANGELOG.md', 'README.md', 'U...
# 4997  ['Caldera-license.pdf', 'README.md', 'last1120...
# 4998  ['.gitignore', 'Classes', 'Default-568h@2x.png...
# 4999  ['.gitattributes', '.gitignore', '.gitmodules'...
#
#                                   Name                            Domain  \
# 0            freeCodeCamp/freeCodeCamp                     Documentation
# 1                       twbs/bootstrap      Web libraries and frameworks
# 2                                d3/d3      Web libraries and frameworks
# 3                       facebook/react      Web libraries and frameworks
# 4                   angular/angular.js      Web libraries and frameworks
# ...                                ...                               ...
# 4995      Yalantis/FlipViewPager.Draco  Non-web libraries and frameworks
# 4996               ScottHamper/Cookies      Web libraries and frameworks
# 4997                mortdeus/legacy-cc                    Software tools
# 4998  B-Sides/ELCImagePickerController  Non-web libraries and frameworks
# 4999                     mapnik/mapnik  Non-web libraries and frameworks
#
#                                            clean_readme  english_readme  \
# 0     freeCodeCamp.org's open-source codebase and cu...        1.000000
# 1     Bootstrap Sleek, intuitive, and powerful front...        0.979592
# 2     D3: Data-Driven Documents D3 (or D3.js) is a J...        1.000000
# 3     React  React is a JavaScript library for build...        1.000000
# 4     AngularJS AngularJS lets you write client-side...        1.000000
# ...                                                 ...             ...
# 4995  Changes: Made clickable views like a button cl...        0.937500
# 4996  Cookies.js Cookies.js is a small client-side j...        1.000000
# 4997  legacy-cc The earliest versions of the very fi...        1.000000
# 4998  ELCImagePickerController A clone of the UIImag...        1.000000
# 4999  _/ _/ _/ _/ _/_/ _/_/ _/_/_/ _/_/_/ _/_/_/ _/ ...        0.909091
#
#                                       clean_description  english_description
# 0     freeCodeCamp.org's open source codebase and cu...                  1.0
# 1     The most popular HTML, CSS, and JavaScript fra...                  1.0
# 2     Bring data to life with SVG, Canvas and HTML. ...                  1.0
# 3     A declarative, efficient, and flexible JavaScr...                  1.0
# 4               AngularJS - HTML enhanced for web apps!                  1.0
# ...                                                 ...                  ...
# 4995  This project aims to provide a working page fl...                  1.0
# 4996  JavaScript Client-Side Cookie Manipulation Lib...                  1.0
# 4997  The earliest versions of the very first c comp...                  1.0
# 4998  A clone of the UIImagePickerController using t...                  1.0
# 4999  Mapnik is an open source toolkit for developin...                  1.0
#
# [5000 rows x 15 columns]

# %%
df['clean_readme'] = df['Readme'].astype('str').apply(clean_text)

# %%
df
# Out:
#          Stars    Forks                                        Description  \
# 0     323943.0  25410.0  freeCodeCamp.org's open source codebase and cu...
# 1     150012.0  71296.0  The most popular HTML, CSS, and JavaScript fra...
# 2      96800.0  22341.0  Bring data to life with SVG, Canvas and HTML. ...
# 3     168294.0  33061.0  A declarative, efficient, and flexible JavaScr...
# 4      59608.0  28135.0            AngularJS - HTML enhanced for web apps!
# ...        ...      ...                                                ...
# 4995    1850.0    349.0  This project aims to provide a working page fl...
# 4996    1780.0    178.0  JavaScript Client-Side Cookie Manipulation Lib...
# 4997    3138.0    300.0  The earliest versions of the very first c comp...
# 4998    1668.0    441.0  A clone of the UIImagePickerController using t...
# 4999    2926.0    722.0  Mapnik is an open source toolkit for developin...
#
#                                                  Readme  \
# 0     ![freeCodeCamp.org Social Banner](https://s3.a...
# 1     <p align="center">\n  <a href="https://getboot...
# 2     # D3: Data-Driven Documents\n\n<a href="https:...
# 3     # [React](https://reactjs.org/) &middot; [![Gi...
# 4     AngularJS [![CircleCI](https://circleci.com/gh...
# ...                                                 ...
# 4995  # Changes:\n\n  * Made clickable views like a ...
# 4996  # Cookies.js\n\nCookies.js is a small client-s...
# 4997  legacy-cc\n=========\n\nThe earliest versions ...
# 4998  # ELCImagePickerController\n\n*A clone of the ...
# 4999  ```\n    _/      _/                           ...
#
#                                               Languages  \
# 0     ['JavaScript', 'CSS', 'Shell', 'HTML', 'EJS', ...
# 1     ['JavaScript', 'HTML', 'SCSS', 'CSS', 'PowerSh...
# 2                                        ['JavaScript']
# 3     ['JavaScript', 'HTML', 'CSS', 'C++', 'TypeScri...
# 4         ['JavaScript', 'HTML', 'Shell', 'PHP', 'CSS']
# ...                                                 ...
# 4995                                           ['Java']
# 4996                      ['JavaScript', 'CSS', 'HTML']
# 4997                                  ['C', 'Assembly']
# 4998                            ['Objective-C', 'Ruby']
# 4999  ['XSLT', 'C++', 'Python', 'HTML', 'JavaScript'...
#
#                                       Licence  Releases  Status  \
# 0     BSD 3-Clause "New" or "Revised" License       0.0    True
# 1                                 MIT License      69.0    True
# 2     BSD 3-Clause "New" or "Revised" License     167.0    True
# 3                                 MIT License      96.0    True
# 4                                 MIT License       0.0    True
# ...                                       ...       ...     ...
# 4995                                      NaN       0.0    True
# 4996                            The Unlicense      10.0    True
# 4997                                      NaN       0.0    True
# 4998                                      NaN       1.0    True
# 4999   GNU Lesser General Public License v2.1      13.0    True
#
#                                                Contents  \
# 0     ['.dockerignore', '.editorconfig', '.eslintign...
# 1     ['.babelrc.js', '.browserslistrc', '.bundlewat...
# 2     ['.gitignore', 'API.md', 'CHANGES.md', 'ISSUE_...
# 3     ['.circleci', '.codesandbox', '.editorconfig',...
# 4     ['.circleci', '.editorconfig', '.eslintignore'...
# ...                                                 ...
# 4995  ['.gitignore', 'README.md', 'build.gradle', 'f...
# 4996  ['.gitignore', 'CHANGELOG.md', 'README.md', 'U...
# 4997  ['Caldera-license.pdf', 'README.md', 'last1120...
# 4998  ['.gitignore', 'Classes', 'Default-568h@2x.png...
# 4999  ['.gitattributes', '.gitignore', '.gitmodules'...
#
#                                   Name                            Domain  \
# 0            freeCodeCamp/freeCodeCamp                     Documentation
# 1                       twbs/bootstrap      Web libraries and frameworks
# 2                                d3/d3      Web libraries and frameworks
# 3                       facebook/react      Web libraries and frameworks
# 4                   angular/angular.js      Web libraries and frameworks
# ...                                ...                               ...
# 4995      Yalantis/FlipViewPager.Draco  Non-web libraries and frameworks
# 4996               ScottHamper/Cookies      Web libraries and frameworks
# 4997                mortdeus/legacy-cc                    Software tools
# 4998  B-Sides/ELCImagePickerController  Non-web libraries and frameworks
# 4999                     mapnik/mapnik  Non-web libraries and frameworks
#
#                                            clean_readme  english_readme  \
# 0     freeCodeCamp.org's open-source codebase and cu...        1.000000
# 1      Bootstrap Sleek, intuitive, and powerful fron...        0.979592
# 2     D3: Data-Driven Documents D3 (or D3.js) is a J...        1.000000
# 3     React React is a JavaScript library for buildi...        1.000000
# 4     AngularJS AngularJS lets you write client-side...        1.000000
# ...                                                 ...             ...
# 4995  Changes: Made clickable views like a button cl...        0.937500
# 4996  Cookies.js Cookies.js is a small client-side j...        1.000000
# 4997  legacy-cc The earliest versions of the very fi...        1.000000
# 4998  ELCImagePickerController A clone of the UIImag...        1.000000
# 4999  Mapnik is an open source toolkit for developin...        0.909091
#
#                                       clean_description  english_description
# 0     freeCodeCamp.org's open source codebase and cu...                  1.0
# 1     The most popular HTML, CSS, and JavaScript fra...                  1.0
# 2     Bring data to life with SVG, Canvas and HTML. ...                  1.0
# 3     A declarative, efficient, and flexible JavaScr...                  1.0
# 4               AngularJS - HTML enhanced for web apps!                  1.0
# ...                                                 ...                  ...
# 4995  This project aims to provide a working page fl...                  1.0
# 4996  JavaScript Client-Side Cookie Manipulation Lib...                  1.0
# 4997  The earliest versions of the very first c comp...                  1.0
# 4998  A clone of the UIImagePickerController using t...                  1.0
# 4999  Mapnik is an open source toolkit for developin...                  1.0
#
# [5000 rows x 15 columns]

# %%
df['clean_description'] = df['Description'].astype('str').apply(clean_text)
df
# Out:
#          Stars    Forks                                        Description  \
# 0     323943.0  25410.0  freeCodeCamp.org's open source codebase and cu...
# 1     150012.0  71296.0  The most popular HTML, CSS, and JavaScript fra...
# 2      96800.0  22341.0  Bring data to life with SVG, Canvas and HTML. ...
# 3     168294.0  33061.0  A declarative, efficient, and flexible JavaScr...
# 4      59608.0  28135.0            AngularJS - HTML enhanced for web apps!
# ...        ...      ...                                                ...
# 4995    1850.0    349.0  This project aims to provide a working page fl...
# 4996    1780.0    178.0  JavaScript Client-Side Cookie Manipulation Lib...
# 4997    3138.0    300.0  The earliest versions of the very first c comp...
# 4998    1668.0    441.0  A clone of the UIImagePickerController using t...
# 4999    2926.0    722.0  Mapnik is an open source toolkit for developin...
#
#                                                  Readme  \
# 0     ![freeCodeCamp.org Social Banner](https://s3.a...
# 1     <p align="center">\n  <a href="https://getboot...
# 2     # D3: Data-Driven Documents\n\n<a href="https:...
# 3     # [React](https://reactjs.org/) &middot; [![Gi...
# 4     AngularJS [![CircleCI](https://circleci.com/gh...
# ...                                                 ...
# 4995  # Changes:\n\n  * Made clickable views like a ...
# 4996  # Cookies.js\n\nCookies.js is a small client-s...
# 4997  legacy-cc\n=========\n\nThe earliest versions ...
# 4998  # ELCImagePickerController\n\n*A clone of the ...
# 4999  ```\n    _/      _/                           ...
#
#                                               Languages  \
# 0     ['JavaScript', 'CSS', 'Shell', 'HTML', 'EJS', ...
# 1     ['JavaScript', 'HTML', 'SCSS', 'CSS', 'PowerSh...
# 2                                        ['JavaScript']
# 3     ['JavaScript', 'HTML', 'CSS', 'C++', 'TypeScri...
# 4         ['JavaScript', 'HTML', 'Shell', 'PHP', 'CSS']
# ...                                                 ...
# 4995                                           ['Java']
# 4996                      ['JavaScript', 'CSS', 'HTML']
# 4997                                  ['C', 'Assembly']
# 4998                            ['Objective-C', 'Ruby']
# 4999  ['XSLT', 'C++', 'Python', 'HTML', 'JavaScript'...
#
#                                       Licence  Releases  Status  \
# 0     BSD 3-Clause "New" or "Revised" License       0.0    True
# 1                                 MIT License      69.0    True
# 2     BSD 3-Clause "New" or "Revised" License     167.0    True
# 3                                 MIT License      96.0    True
# 4                                 MIT License       0.0    True
# ...                                       ...       ...     ...
# 4995                                      NaN       0.0    True
# 4996                            The Unlicense      10.0    True
# 4997                                      NaN       0.0    True
# 4998                                      NaN       1.0    True
# 4999   GNU Lesser General Public License v2.1      13.0    True
#
#                                                Contents  \
# 0     ['.dockerignore', '.editorconfig', '.eslintign...
# 1     ['.babelrc.js', '.browserslistrc', '.bundlewat...
# 2     ['.gitignore', 'API.md', 'CHANGES.md', 'ISSUE_...
# 3     ['.circleci', '.codesandbox', '.editorconfig',...
# 4     ['.circleci', '.editorconfig', '.eslintignore'...
# ...                                                 ...
# 4995  ['.gitignore', 'README.md', 'build.gradle', 'f...
# 4996  ['.gitignore', 'CHANGELOG.md', 'README.md', 'U...
# 4997  ['Caldera-license.pdf', 'README.md', 'last1120...
# 4998  ['.gitignore', 'Classes', 'Default-568h@2x.png...
# 4999  ['.gitattributes', '.gitignore', '.gitmodules'...
#
#                                   Name                            Domain  \
# 0            freeCodeCamp/freeCodeCamp                     Documentation
# 1                       twbs/bootstrap      Web libraries and frameworks
# 2                                d3/d3      Web libraries and frameworks
# 3                       facebook/react      Web libraries and frameworks
# 4                   angular/angular.js      Web libraries and frameworks
# ...                                ...                               ...
# 4995      Yalantis/FlipViewPager.Draco  Non-web libraries and frameworks
# 4996               ScottHamper/Cookies      Web libraries and frameworks
# 4997                mortdeus/legacy-cc                    Software tools
# 4998  B-Sides/ELCImagePickerController  Non-web libraries and frameworks
# 4999                     mapnik/mapnik  Non-web libraries and frameworks
#
#                                            clean_readme  english_readme  \
# 0     freeCodeCamp.org's open-source codebase and cu...        1.000000
# 1      Bootstrap Sleek, intuitive, and powerful fron...        0.979592
# 2     D3: Data-Driven Documents D3 (or D3.js) is a J...        1.000000
# 3     React React is a JavaScript library for buildi...        1.000000
# 4     AngularJS AngularJS lets you write client-side...        1.000000
# ...                                                 ...             ...
# 4995  Changes: Made clickable views like a button cl...        0.937500
# 4996  Cookies.js Cookies.js is a small client-side j...        1.000000
# 4997  legacy-cc The earliest versions of the very fi...        1.000000
# 4998  ELCImagePickerController A clone of the UIImag...        1.000000
# 4999  Mapnik is an open source toolkit for developin...        0.909091
#
#                                       clean_description  english_description
# 0     freeCodeCamp.org's open source codebase and cu...                  1.0
# 1     The most popular HTML, CSS, and JavaScript fra...                  1.0
# 2     Bring data to life with SVG, Canvas and HTML. ...                  1.0
# 3     A declarative, efficient, and flexible JavaScr...                  1.0
# 4               AngularJS - HTML enhanced for web apps!                  1.0
# ...                                                 ...                  ...
# 4995  This project aims to provide a working page fl...                  1.0
# 4996  JavaScript Client-Side Cookie Manipulation Lib...                  1.0
# 4997  The earliest versions of the very first c comp...                  1.0
# 4998  A clone of the UIImagePickerController using t...                  1.0
# 4999  Mapnik is an open source toolkit for developin...                  1.0
#
# [5000 rows x 15 columns]

# %%
df.to_csv('GHDomains.csv', index=False)
